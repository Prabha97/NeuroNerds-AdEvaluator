# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
path = 'E:/NeuroNerds/NeuroNerds-AdEvaluator/Project Data/Attention Data.csv'

# %%
data = pd.read_csv(path)
data
# Out:
#       TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  Theta_TP9  \
# 0       24:15.3   0.751643   1.137732   1.241092    0.434002   0.432456
# 1       24:15.8   0.751643   1.137732   1.299211    0.434002   0.432456
# 2       24:16.3   0.751643   1.156090   0.558158    0.434002   0.432456
# 3       24:16.8   0.796775   0.867685   0.994092    0.549118   0.868472
# 4       24:17.3   0.775548   0.786956   1.083485    0.519082   0.784558
# ...         ...        ...        ...        ...         ...        ...
# 11838   06:45.8   0.986110   0.480529   0.591422    0.967558   0.809593
# 11839   06:46.4   0.905541  -0.027661   0.190887    0.845574   0.728109
# 11840   06:46.9   0.927426   0.148461   0.143809    0.309474   0.745079
# 11841   06:47.4   0.859555   0.190864   0.118321    0.143381   0.669280
# 11842   06:48.0   0.934166   0.348056   0.046701    0.143381   0.716854
#
#        Theta_AF7  Theta_AF8  Theta_TP10  Alpha_TP9  ...    Gyro_X    Gyro_Y  \
# ...

# %%
data.columns
# Out:
# Index(['TimeStamp', 'Delta_TP9', 'Delta_AF7', 'Delta_AF8', 'Delta_TP10',
#        'Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10', 'Alpha_TP9',
#        'Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10', 'Beta_TP9', 'Beta_AF7',
#        'Beta_AF8', 'Beta_TP10', 'Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8',
#        'Gamma_TP10', 'RAW_TP9', 'RAW_AF7', 'RAW_AF8', 'RAW_TP10', 'AUX_RIGHT',
#        'Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z', 'Gyro_X',
#        'Gyro_Y', 'Gyro_Z', 'HeadBandOn', 'HSI_TP9', 'HSI_AF7', 'HSI_AF8',
#        'HSI_TP10', 'Battery', 'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11843 entries, 0 to 11842
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TimeStamp        11843 non-null  object
#  1   Delta_TP9        10972 non-null  float64
#  2   Delta_AF7        10972 non-null  float64
#  3   Delta_AF8        10972 non-null  float64
#  4   Delta_TP10       10972 non-null  float64
#  5   Theta_TP9        10972 non-null  float64
#  6   Theta_AF7        10972 non-null  float64
#  7   Theta_AF8        10972 non-null  float64
#  8   Theta_TP10       10972 non-null  float64
#  9   Alpha_TP9        10972 non-null  float64
#  10  Alpha_AF7        10972 non-null  float64
#  11  Alpha_AF8        10972 non-null  float64
#  12  Alpha_TP10       10972 non-null  float64
#  13  Beta_TP9         10972 non-null  float64
#  14  Beta_AF7         10972 non-null  float64
#  15  Beta_AF8         10972 non-null  float64
# ...

# %%
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# RAW_TP9            872
# RAW_AF7            872
# RAW_AF8            872
# RAW_TP10           872
# AUX_RIGHT          872
# Gamma_AF8          871
# Delta_TP9          871
# Accelerometer_X    871
# Accelerometer_Y    871
# Accelerometer_Z    871
# Gyro_X             871
# Gyro_Y             871
# Gyro_Z             871
# HeadBandOn         871
# HSI_TP9            871
# HSI_AF7            871
# HSI_AF8            871
# Gamma_TP10         871
# Gamma_AF7          871
# Battery            871
# Gamma_TP9          871
# Delta_AF7          871
# Delta_AF8          871
# Delta_TP10         871
# Theta_TP9          871
# Theta_AF7          871
# Theta_AF8          871
# Theta_TP10         871
# Alpha_TP9          871
# Alpha_AF7          871
# Alpha_AF8          871
# Alpha_TP10         871
# Beta_TP9           871
# Beta_AF7           871
# Beta_AF8           871
# Beta_TP10          871
# HSI_TP10           871
# TimeStamp            0
# Class                0
# dtype: int64

# %%
#remove null values 
for col in data.columns:
    data= data.dropna(subset=[col],axis=0)
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# TimeStamp          0
# Gyro_X             0
# RAW_AF7            0
# RAW_AF8            0
# RAW_TP10           0
# AUX_RIGHT          0
# Accelerometer_X    0
# Accelerometer_Y    0
# Accelerometer_Z    0
# Gyro_Y             0
# Gamma_TP10         0
# Gyro_Z             0
# HeadBandOn         0
# HSI_TP9            0
# HSI_AF7            0
# HSI_AF8            0
# HSI_TP10           0
# Battery            0
# RAW_TP9            0
# Gamma_AF8          0
# Delta_TP9          0
# Alpha_TP9          0
# Delta_AF7          0
# Delta_AF8          0
# Delta_TP10         0
# Theta_TP9          0
# Theta_AF7          0
# Theta_AF8          0
# Theta_TP10         0
# Alpha_AF7          0
# Gamma_AF7          0
# Alpha_AF8          0
# Alpha_TP10         0
# Beta_TP9           0
# Beta_AF7           0
# Beta_AF8           0
# Beta_TP10          0
# Gamma_TP9          0
# Class              0
# dtype: int64

# %%
data = data.set_index('TimeStamp')

# %%
data.shape
# Out:
# (10971, 38)

# %%
data['Class'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
data.isnull().values.any()
# Out:
# False

# %%
#mapping numbers
data['Class'] = data['Class'].map({'Low' :0, 'Medium' :1, 'High' :2}).astype(int)
data.head()
# Out:
#            Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  Theta_TP9  Theta_AF7  \
# TimeStamp
# 24:15.3     0.751643   1.137732   1.241092    0.434002   0.432456   0.364035
# 24:15.8     0.751643   1.137732   1.299211    0.434002   0.432456   0.364035
# 24:16.3     0.751643   1.156090   0.558158    0.434002   0.432456   0.287083
# 24:16.8     0.796775   0.867685   0.994092    0.549118   0.868472   0.103581
# 24:17.3     0.775548   0.786956   1.083485    0.519082   0.784558   0.210304
#
#            Theta_AF8  Theta_TP10  Alpha_TP9  Alpha_AF7  ...    Gyro_X  \
# TimeStamp                                               ...
# 24:15.3     1.142506    0.530501   1.093901   0.212564  ...  6.624451
# 24:15.8     1.170195    0.530501   1.093901   0.212564  ...  5.121613
# 24:16.3     0.384314    0.530501   1.093901   0.457129  ...  5.016937
# 24:16.8     0.368374    0.769166   1.216370   0.426305  ...  5.854340
# 24:17.3     0.384292    0.788158   1.221839   0.456308  ...  5.473022
#
# ...

# %%
data.to_csv('E:/NeuroNerds/NeuroNerds-AdEvaluator/Project Data/Preprocessed Attention Data.csv', index=False)
